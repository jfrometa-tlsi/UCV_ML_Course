# %% [markdown]
# # 📈 Proyecto Final: Machine Learning para Business Analytics
# # Título del Proyecto: [Ej: Predicción de Churn con Impacto Económico]
#
# ## Autor: [Ej: Jorge Israel Frometa Moya]
#
# ## 📋 1. Definición del Problema de Negocio
# - **Objetivo:** [Establece el objetivo del análisis]
# - **KPI(s) afectado(s):** [Ej: Tasa de retención, margen operativo, coste logístico]
# - **Pregunta empresarial:** [Ej: ¿Podemos predecir qué clientes se irán en los próximos 3 meses?]
#
# Enlace a sitio con datasets públicos: [ https://www.kaggle.com/datasets/]( https://www.kaggle.com/datasets/)

# %%
# Escribe los hallazgos aquí (Convierte la celda a Markdown)

# %% [markdown]
# ## 🧹 2. Preparación y Calidad de Datos (EDA)
# ### Carga, inspección y limpieza

# %% [markdown]
# ```
# Guía de como realizar esta parte:
#
# Comienza por importar la biblioteca de pandas: import pandas as pd.
#
# Utiliza la función read_csv() para cargar el archivo CSV en un dataframe de pandas. Especifica la ruta en los paréntesis, por ejemplo: pd.read_csv("ruta_al_archivo.csv").
#
# Asigna al dataframe resultante al nombre de una variable, por ejemplo: data = pd.read_csv("ruta_al_archivo.csv").
#
# Utiliza el método head() sobre el dataframe para mostrar las primeras 10 filas, por ejemplo: data.head(10).
#
# Utiliza el nombre de la variable del dataframe seguido del método isnull() para crear un dataframe booleano donde «verdadero» indique un valor nulo y «falso» indique un valor no nulo.
#
# Utiliza el método sum() en el dataframe booleano para contar la cantidad de valores verdaderos (i.e., la cantidad de valores nulos) en cada columna.
#
# Si unes ambos pasos, el código se verá así: data.isnull().sum()
#
# Revisa si todas las columnas de interés están en un formato numérico aceptable (int, float) para los posteriores procesamientos (ej. con data.info()).
#
# Define que hacer con los casos nulos, la conversión a numéricos en caso de ser necesario.
#
# Este código asume que el nombre del datafrme de pandas es «data». Si tu dataframe tiene un nombre diferente, reemplaza «data» con el nombre correcto de la variable.
#
# ```

# %%
#Escribe tu código aquí

# %% [markdown]
# ### Principales hallazgos EDA
#
# [Ej: Hay un 5% de valores nulos en la columna Y]

# %%
# Escribe los hallazgos aquí (Convierte la celda a Markdown)

# %% [markdown]
# ## 🧠  3. Modelado y Selección
# ### Preparación de datos para modelado

# %% [markdown]
# ```
# Una vez que tengas listo el dataset, puedes utilizar la biblioteca scikit-learn para separar los datos en grupos de entrenamiento y de evaluación con la función train_test_split().
#
# Primero, puedes crear un dataframe de pandas «X» con todas las columnas predictoras. Puedes crear una serie de pandas «y» solamente con la columna que representa la variable a predecir.
#
# A continuación, pueder usar la función train_test_split() para separar los datos en grupos de entrenamiento y de evaluación. Puedes pasar las variables X e Y como argumentos junto con el argumento test_size para especificar el porcentaje del dataset que se deberá asignar al grupo de evaluación (en este caso, el 20 %). También puedes utilizar el argumento random_state para determinar un valor fijo de tal manera que, cada vez que se ejecute el código, se produzca la misma división.
#
# La función train_test_split() devuelve cuatro variables: X_train, X_test, y_train y y_test. X_train e y_train representan el grupo de entrenamiento, mientras que X_test e y_test representan el grupo de evaluación. Puedes utilizar estas variable para entrenar y evaluar tus modelos de aprendizaje automático.
#
# Ten en cuenta que es importante dividir los datos en grupos de entrenamiento y de evaluación para evitar el sobreajuste y permitir que se evalúe el rendimiento del modelo con datos que desconoce.
# ```

# %%
#Escribe tu código aquí

# %% [markdown]
# ### Entrenamiento de al menos un modelo

# %% [markdown]
# ```
# Debes importar las bibliotecas y clases necesarias, tales como la clase RandomForestClassifier o LogisticRegression de scikit-learn.
#
# Una vez hayas hecho esto, podrás crear una instancia de la clase (ej. RandomForestClassifier configurando los hiperparámetros max_depth y random_state en 150 y 42, respectivamente). Puedes utilizar el método .fit() para entrenar el modelo con los datos de entrenamiento.
#
# ```

# %%
#Escribe tu código aquí

# %% [markdown]
# ## 📉 4. Diagnóstico y Validación

# %% [markdown]
# ```
# A continuación, puedes utilizar el modelo entrenado para hacer predicciones sobre los datos de evaluación con el método .predict(). Puedes almacenar estas predicciones en una variable llamada y_pred.
#
# Después, puedes utilizar la función classification_report() para mostrar en la pantalla un resumen del rendimiento del modelo con los datos de entrenamiento. Esto incluirá métricos tales como la precisión (precission), la exhaustividad (recall) y la puntuación F1 (f1-score) para cada una de las clases a predecir. También puedes utilizar la función accuracy_score() para calcular la exactitud general del modelo con los datos de evaluación.
#
# De ser posible puedes graficar estos resultados.
# ```

# %%
#Escribe tu código aquí

# %% [markdown]
# ## 💰 5. Impacto Económico
# ### Traducción de hallazgos a costes

# %% [markdown]
# ### Ejemplo: Coste de falso positivo vs. falso negativo en euros en un modelo de clasificación de campaña de marketing
#
# ```python
# cost_fp = 50   # Coste de una campaña de retención innecesaria
# cost_fn = 500  # Coste de perder un cliente
#
# # Calcular coste total del modelo
# conf_matrix = confusion_matrix(y_test, y_pred)
# total_cost = conf_matrix[0,1]*cost_fp + conf_matrix[1,0]*cost_fn
# print(f"Coste total del modelo: €{total_cost}")
# ```

# %%
#Escribe tu código aquí

# %% [markdown]
# ## 🎯 6. Recomendaciones Ejecutivas
# ### 6.1 Storytelling para la gerencia
#
# - Problema: [Descripción breve]
# - Solución: [Modelo elegido y por qué]
# - Impacto: [En euros y KPIs]

# %% [markdown]
# Escribe los hallazgos aquí

# %%
# Escribe los hallazgos aquí (Convierte la celda a Markdown)
